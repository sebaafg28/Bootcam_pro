# %%
contador = 0
while contador <= 4 :
    contador = contador + 1 
    print(contador)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
num = 0
while num != 10:
    num = int(input('introduzca su numero'))
    if num != 10: 
        print(' su numero no es 10, siga intentando')
    else:
        print('su numero es correcto ')
# Out:
#  su numero no es 10, siga intentando
#  su numero no es 10, siga intentando
# su numero es correcto

# %%
intentos = 5
num_var = 7
num_usuario = 2
if num_usuario != 7:
    while intentos >= 1:
        num_usuario = int(input('introduzca su numero'))
        intentos = intentos - 1
        if num_usuario < 7 :
            print('el numero introducido es menor al numero secreto ')
        elif num_usuario > 7 :
            print('el numero introducido es mayor al numero secreto ')
        else :
            print('adivinaste el numero secreto, felicidades')
            break
        print(f'le quedan {intentos} intentos')
else :
    print('adivinaste el numero secreto, felicidades')
# Out:
# el numero introducido es menor al numero secreto
# le quedan 4 intentos
# el numero introducido es menor al numero secreto
# le quedan 3 intentos
# el numero introducido es menor al numero secreto
# le quedan 2 intentos
# el numero introducido es menor al numero secreto
# le quedan 1 intentos
# el numero introducido es menor al numero secreto
# le quedan 0 intentos

# %%
def suma(numero1,numero2):
    sum = numero1 + numero2
    print(sum)
suma(13 , 42)
# Out:
# 55

# %%
nombre_usuario = input('ingrese su nombre')

producto_usuario = input('ingrese el nombre de su producto')

cantidad_usuario = int(input('ingrese la cantidad de producto que desea'))

def compra(usuario , producto, cantidad):

    print(f'el cliente es :{usuario}, el producto que llevara es {producto}, la cantidad es {cantidad}.')

compra(nombre_usuario, producto_usuario, cantidad_usuario)
# Out:
# el cliente es :sss, el producto que llevara es pan, la cantidad es 4.

# %%
lista_animales = ['leon', 'tigre','elefante','pavo real','avestruz']
for animal in lista_animales:
    print(animal)
# Out:
# leon
# tigre
# elefante
# pavo real
# avestruz

# %%
def extraer_dinero(cantidad_a_extraer):
    return cantidad_a_extraer
dinero_disponible = extraer_dinero(20000)
print(dinero_disponible)
def comprar_coquita(dinero_disponible):
    if dinero_disponible >= 5000 :
