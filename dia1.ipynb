# %%
print("LISTA DE CONCURSANTES")
print('los concursantes son:')
def concursantes(): 
    nombre =input('cual es su nombre')
     
    print(f' {nombre} {apellido}')


concursantes()
concursantes()
concursantes()
# Out:
# LISTA DE CONCURSANTES
# los concursantes son:
#   kfkd
#  dfdf fdf
#  dfdf fdfd

# %%
#declaracion de variables
caramelos = int(input('cuantos caramelos desea'))
ninos = int(input('cuantos ninos hay'))

#division
total_recibido = caramelos//ninos

#impresion
print(f'los ninos reciben {total_recibido} caramelos cada uno')
# Out:
# los ninos reciben 10 caramelos cada uno

# %%
print('Bienvenido a la concesionaria Gonzalez')
nombre_vehiculo = input('que marca de auto prefiere?')
color_vehiculo = input('que color de auto quiere?')
uso_vehiculo = input('desea un vehiculo 0km o usado?')

def pedido(marca, color, uso):
    print(f'su vehiculo esta en camino {marca}, {color}, {uso}')
    print('su vehiculo ha llegado al destino.')
pedido(nombre_vehiculo , color_vehiculo, uso_vehiculo)
# Out:
# Bienvenido a la concesionaria Gonzalez
# su vehiculo esta en camino ferrari, dorado, 0km
# su vehiculo ha llegado al destino.

# %%
impuesto = 10/100
def producto():
    prod1 = int(input('agregue el precio de su producto en GS'))
    prod2 = int(input('agregue el precio de su otro producto en GS'))
    suma_gasto = prod1 + prod2 
    total_impuesto = suma_gasto*impuesto
    total_gasto = suma_gasto - total_impuesto
    print (total_gasto)
producto()
# Out:
# 58500.0

# %%
nombre = 'luis'
apellido = 'alvarez'

print(f'hola, soy nuevo y mi nombre es {nombre} {apellido}')
# Out:
# hola, soy nuevo y mi nombre es luis alvarez

# %%
cantidad_de_manzanas = 20
cantidad_de_naranja = 15
#suma
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranja
print('tengo',cantidad_de_frutas, 'frutas')
frutas_vendidas = 23
print('vendi', frutas_vendidas, 'frutas')
#resta
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print('me quedan',frutas_restantes, 'frutas')
# Out:
# tengo 35 frutas
# vendi 23 frutas
# me quedan 12 frutas

# %%
producto1 = 'lomito'
costo_prod = 25000

producto2 = 'coca'
costo_prod2 = 5000

capital = 50000
dolar = 6650  
#suma
costo_total = costo_prod + costo_prod2 
print('el costo total es:', costo_total)
queda = capital - costo_total 
print('me queda:', queda)

#division
queda_dolar = queda/dolar
print('me sobra en dolares:',queda_dolar)
# Out:
# el costo total es: 30000
# me queda: 20000
# me sobra en dolares: 3.007518796992481

# %%
edad = 98
altura = 1,68
nombre = 'isma'
feliz = True
print(edad)
print(altura)
print(nombre)
print(feliz)
# Out:
# 98
# (1, 68)
# isma
# True

# %%
nom = 'sebas'
edad = 18
ciudad = 'Mariano Roque Alonso'
print(nom)
print(edad)
print(ciudad)
# Out:
# sebas
# 18
# Mariano Roque Alonso

# %%
fruta = 'naranja'
print(fruta)

fruta = 'manzana'
print(fruta)
# Out:
# naranja
# manzana

# %%
print("hola mundo")
# Out:
# hola mundo
