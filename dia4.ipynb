# %%
datos_usuario = {}
print(datos_usuario)

datos_usuario['nombre'] = input('ingrese su nombre')
print(datos_usuario) 

datos_usuario['apellido'] = input('ingrese su apellido')
print(datos_usuario)

datos_usuario['edad'] = input('ingrese su edad')
print(datos_usuario)

datos_usuario['sexo'] = input('ingrese su sexo') 
print(datos_usuario)

datos_usuario['telefono'] = input('ingrese su numero telefonico')
print(datos_usuario)

datos_usuario['correo'] = input('ingrese su correo')
print(datos_usuario)
# Out:
# {}
# {'nombre': 'sebas'}
# {'nombre': 'sebas', 'apellido': 'fleitas'}
# {'nombre': 'sebas', 'apellido': 'fleitas', 'edad': '18'}
# {'nombre': 'sebas', 'apellido': 'fleitas', 'edad': '18', 'sexo': 'masculino'}
# {'nombre': 'sebas', 'apellido': 'fleitas', 'edad': '18', 'sexo': 'masculino', 'telefono': '099999'}
# {'nombre': 'sebas', 'apellido': 'fleitas', 'edad': '18', 'sexo': 'masculino', 'telefono': '099999', 'correo': 'seba@sdjsd'}

# %%
contac = input('ingrese el nombre de su contacto' )
datos = input('ingrese los datos de su contacto')

agenda = {}
print(agenda)

opcion = input('mostrar = 1, crear = 2, modificar = 3')
if opcion == '1':
    print(agenda)
elif opcion == '2':
   nuevo_contac = input('ingrese el nombre de su nuevo contacto')
   agenda[nuevo_contac] = nuevo_contac{'tel' : input('ingrese su telefono', 'correo' : input('ingrese su correo'))}

# %%
tarjeta_personal={}

def crear():
    clave=input("Ingrese el nombre de la clave")
    valor=input("Ingrese un valor para la clave")
    tarjeta_personal[clave]=valor


def modificar():
    clave=input("Ingrese el nombre de la clave a modificar")
    valor=input("Ingrese un nuevo valor")
    tarjeta_personal[clave]=valor

def eliminar():
    clave= input("Ingrese el nombre de la clave que desea eliminar")
    del tarjeta_personal[clave]


while True:
    opcion=int(input("Ingrese una opcion: 1. Crear, 2. Modificar, 3. Eliminar, 4. Salir"))
    if opcion == 1:
        crear()
        print(tarjeta_personal)
    elif opcion ==2:
        modificar()
        print(tarjeta_personal)
    elif opcion==3:
        eliminar()
        print(tarjeta_personal)
    else :
        break
# Out:
# {'nombre': 'sebas'}
# {'nombre': 'ssss'}
